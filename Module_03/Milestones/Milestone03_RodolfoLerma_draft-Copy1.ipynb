# %% [markdown]
# # Milestone 03 - Artificial Neural Networks
#
# ## Author - Rodolfo Lerma

# %% [markdown]
# # Problem
#
# Continue from Milestone 2 to build a simple neural netwok, a DNN & a RNN model and compare performance.
#
# # Abstract:
#
# The capstone project focuses on diaper manufacturing quality. Generally, to ensure or predict quality, a diaper manufacturer need s to monitor every step of the manufacturing process with sensors such as heat sensors, glue sensors, glue level, etc.
# For this capstone project, we will use the SECOM manufacturing Data Set from the UCI Machine Learning Repository.
#
# The analysis is is divided the following way:
#
# ### Summary from Milestone 01 & Milestone 02
#
#
# ### Data Formatting
# - **Merging Data**
# - **Missing Data**
# - **Repeated Values (Columns with the same value)**
#
#
# ### Feature Selection
#
# ### Analysis
# - **Normalizing features from 0-1**
# - **Split Data and Class Imbalance**
#     - Split Data
#     - Class Imbalance
# - **Simple Neural Network**
# - **Deep Neural Network**
# - **Recurrent Neural Network**
#
# ### Summary of Models Performance

# %% [markdown]
# # Summary from Milestone 01 & 02

# %% [markdown]
# ## Milestone 01
#
# - For this analysis we initially had 590 features + date and the target variable (quality of the diaper as either good or bad). After some cleaning (removing columns with a lot of missing values and columns with the same value repeated in all rows) we ended up with a data frame with 538 features + data + target variable.
#
#
# - In this case it seems that the `Wrapper` feature selection method is the one offering a better selection to model the quality of the diapers by means of the manufacturing process.
#
#
# - The class imbalance problem was solved my means of re-sampling.
#
# | Target | -1 | 1294 |
# | --- | --- | --- |
# | Target | 1 | 99 |
#
# ## Milestone 02
#
# - From this analysis the best model was the one from the `Random Forest` with the following performance values:
#
# | Performance | Value |
# | -- | --|
# | Accuracy | 0.9713 |
# | Error Rate | 0.0287 |
# | Precision | 0.9922 |
# | Recall | 0.9769|
# | F1 Score | 0.9845 |
#
# - The best hyperparameters for this model after a random grid search were:
# - `n_estimators`: 70
# - `min_samples_split`: 4
# - `min_samples_lead`:  2
# - `max_depth`: 10
# - `criterion`: gini

# %% [markdown]
# # Data Formatting

# %% [markdown]
# ## Merging Data

# %%
#Loading libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Load File
filename = 'secom.data'
filename2 = 'secom_labels.data'
data = pd.read_csv(filename,header=None, sep = '\s+')
others = pd.read_csv(filename2,header=None,sep = '\s+')

others.columns = ['target', 'date']
df = pd.concat([others,data], axis = 1)
df['date']= pd.to_datetime(df['date']) #date to datetime

# %% [markdown]
# ## Missing Data

# %%
missing_values = []
my_list = df.columns.values.tolist()
y = df.shape
for i in my_list:
    x = df[i].isnull().sum()
    missing_values.append(x)
    
columns_missing = dict(zip(my_list, missing_values))
a = sorted(columns_missing.items(), key=lambda x: x[1], reverse = True)

# %% [markdown]
# As before if more than 15% of data is missing in a column that column would be dropped from this data set at this moment. For other columns with missing data is present depending on how much data is missing is going to be either dropped or imputed.

# %%
missing_columns_names = []
for key, value in columns_missing.items():
    if value > 240: #15% of the data
        x = key
        missing_columns_names.append(x)

# %% [markdown]
# Those columns would be eliminated from the data set, since most of the values are missing.

# %%
df = df.drop(missing_columns_names, axis = 1)
df = df.dropna()

# %% [markdown]
# For this analysis since removing missing data would only take 10% of the available data, those raws are going to be remove. If by removing missing data more than 15% were to be removed other methods would have been explored as: substitution.
# Even at this moment having 540 variables/features is to much to explore and obtain meaninful results, therefore more work has to be done.

# %% [markdown]
# ## Repeated Values (Columns with the same value)

# %%
not_repeated = []
repeated = []
updated_columns = df.columns.values.tolist()
y = df.shape
for i in updated_columns[2:]:
    x = df[i].std()
    if x == 0:
        repeated.append(i)
    else:
        not_repeated.append(i)
df = df.drop(repeated, axis = 1)

categorical = []
numerical = []
updated_columns = df.columns.values.tolist()
y = df.shape
for i in updated_columns:
    x = df[i].dtypes
    if x == object:
        categorical.append(i)
    else:
        numerical.append(i)

# %%
tr = df.iloc[:,0].tolist()
binomial = []
for i in range(len(tr)):
    b = tr[i]
    if b < 0:
        n = 0
    else:
        n = 1
    binomial.append(n)
df['target_binomial'] = binomial

# %%
df.head()
# Out:
#    target                date        0        1          2          3       4  \
# 1      -1 2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294
# 2       1 2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102
# 3      -1 2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204
# 4      -1 2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334
# 5      -1 2008-07-19 17:53:00  2946.25  2432.84  2233.3667  1326.5200  1.5334
#
#           6       7       8  ...      577     582     583     584      585  \
# 1  102.3433  0.1247  1.4966  ...  10.9003  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   9.2721  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   8.5831  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...  10.9698  0.4800  0.4766  0.1045  99.3032
# 5  100.3967  0.1235  1.5287  ...  13.7755  0.4949  0.0189  0.0044   3.8276
#
#       586     587     588       589  target_binomial
# 1  0.0096  0.0201  0.0060  208.2045                0
# 2  0.0584  0.0484  0.0148   82.8602                1
# 3  0.0202  0.0149  0.0044   73.8432                0
# 4  0.0202  0.0149  0.0044   73.8432                0
# 5  0.0342  0.0151  0.0052   44.0077                0
#
# [5 rows x 425 columns]

# %%
df.tail()
# Out:
#       target                date        0        1          2          3  \
# 1537      -1 2008-10-15 18:16:00  3006.22  2525.20  2192.7889  1268.5852
# 1539      -1 2008-10-15 19:24:00  2908.94  2560.99  2187.3444  2882.8558
# 1540      -1 2008-10-15 21:44:00  2996.04  2555.92  2190.7666  3530.2362
# 1541      -1 2008-10-15 22:45:00  3246.31  2499.79  2216.8111  1190.4067
# 1550      -1 2008-10-16 03:56:00  3072.20  2406.47  2195.4444  2914.1792
#
#            4         6       7       8  ...      577     582     583     584  \
# 1537  1.9935  104.5867  0.1268  1.4522  ...  26.7805  0.4942  0.0175  0.0045
# 1539  1.5876   85.4189  0.1235  1.4167  ...  67.4386  0.4987  0.0118  0.0028
# 1540  0.8017   83.8767  0.1249  1.4158  ...  25.2760  0.5011  0.0163  0.0035
# 1541  2.5148  114.5533  0.1230  1.3966  ...  11.8247  0.5021  0.0103  0.0030
# 1550  1.5978   85.1011  0.1235  1.3148  ...  21.7713  0.5034  0.0178  0.0043
#
#          585     586     587     588      589  target_binomial
# 1537  3.5322  0.0199  0.0097  0.0037  48.7045                0
# 1539  2.3583  0.0237  0.0112  0.0038  47.3376                0
# 1540  3.2608  0.0181  0.0123  0.0046  67.6676                0
# 1541  2.0418  0.0266  0.0063  0.0019  23.5979                0
# 1550  3.5459  0.0236  0.0065  0.0022  27.5514                0
#
# [5 rows x 425 columns]

# %% [markdown]
# Thru the code above the data was checked to see if there was any variable that could be considered as categorical (also this helped to checked any column with incorrect values)

# %% [markdown]
# # Feature Selection
#
# From Milestone 01 it was seen that the best Features where does coming from the `Wrapper` Method. For more details on this comparison see **Milestone 01** analysis.

# %%
# Recursive Feature Elimination
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE #Recursive Feature Elimination
from sklearn.linear_model import LinearRegression

estimator = LinearRegression()
selector = RFE(estimator, 50, step=1)

df_numeric = df[numerical]
df_numeric = df_numeric.drop('date', axis = 1)

df_numeric_copy = df_numeric.copy()

target = df_numeric.iloc[:,0]#This is the selection of the Target Variables
df_updated = df_numeric_copy.drop('target', axis='columns')

lol = df_updated.values.tolist()
selector = selector.fit(lol, target)

boolean_values = selector.support_
ranking_values = selector.ranking_
wrapper_columns = df_updated.columns.values.tolist()

#Selection of the features with ranking 1
selected_features = []
unselected_features = []
for i in range(len(wrapper_columns)):
    w = boolean_values[i]
    if w == True:
        b = wrapper_columns[i]
        selected_features.append(b)
    else:
        v = wrapper_columns[i]
        unselected_features.append(v)
# Out:
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass n_features_to_select=50 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
df[selected_features].head()
# Out:
#         12       16        18       34       36        43        45   \
# 1  200.5470   9.2599  191.2872  50.6596  49.3404  352.2445  133.1727
# 2  202.0179   9.3144  192.7035  50.1530  49.8470  364.3782  131.8027
# 3  201.8482   9.6924  192.1557  50.5100  49.4900  363.0273  131.8027
# 4  201.9424  10.3387  191.6037  50.2480  49.7520  353.3400  176.3136
# 5  200.4720   9.2441  191.2280  50.5795  49.4205  360.2873  142.2591
#
#         48        50     53   ...     365     366     367     368     377  \
# 1  145.8445  631.2618  4.590  ...  0.0053  0.0059  0.0081  0.0033  0.0013
# 2  141.0845  637.2655  4.486  ...  0.0054  0.0043  0.0030  0.0037  0.0015
# 3  142.5427  637.3727  4.486  ...  0.0046  0.0049  0.0028  0.0034  0.0014
# 4  138.0882  667.7418  4.624  ...  0.0063  0.0077  0.0052  0.0027  0.0012
# 5  137.6473  640.1936  4.636  ...  0.0095  0.0048  0.0033  0.0027  0.0011
#
#    387     392     446     543     544
# 1  0.0  0.0027  1.5683  0.0078  0.0026
# 2  0.0  0.0020  1.4698  0.0078  0.0026
# 3  0.0  0.0023  1.3141  0.0078  0.0026
# 4  0.0  0.0077  1.2524  0.0078  0.0026
# 5  0.0  0.0081  1.1174  0.0078  0.0026
#
# [5 rows x 50 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Split Data and Class Imbalance

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import *

tr = df.iloc[:,0].tolist()
binomial = []
for i in range(len(tr)):
    b = tr[i]
    if b < 0:
        n = 0
    else:
        n = 1
    binomial.append(n)
df['target_binomial'] = binomial

# %% [markdown]
# ## Normalizing features from 0-1

# %%
from sklearn import preprocessing

label = df['target_binomial']
variables = df[selected_features]

x = variables.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
variables_scaled = pd.DataFrame(x_scaled)

# %%
round_variables = variables_scaled*100
variables_round = round_variables.round()
variables_round = variables_round

# %% [markdown]
# ### Split Data

# %%
#Split the data for variables with high mi value
X_train, X_test, y_train, y_test = train_test_split(variables_scaled, label, test_size=0.30, random_state=42)
X_train_rnn, X_test_rnn, y_train_rnn, y_test_rnn = train_test_split(variables_round, label, test_size=0.30, random_state=42)

# %% [markdown]
# ### Class Imbalance

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE 

sm = SMOTE(random_state=42)

variables_sm, label_sm = sm.fit_resample(variables_scaled, label)
variables_sm_rnn, label_sm_rnn = sm.fit_resample(variables_round, label)

X_train_sm, X_test_sm, y_train_sm, y_test_sm = train_test_split(variables_sm, label_sm, test_size=0.30, random_state=42)
X_train_sm_rnn, X_test_sm_rnn, y_train_sm_rnn, y_test_sm_rnn = train_test_split(variables_sm_rnn, label_sm_rnn, test_size=0.30, random_state=42)

# %% [markdown]
# In summary the variables that are going to be input to the model are:
# - Training:
#     - `X_train_sm`
#     - `y_train_sm`
#
#
# - Testing:
#     - `X_test`
#     - `y_test`

# %% [markdown]
# ## Simple Neural Network
#
# During Assignment 08 a simple and multiyer neural network was created from scratch, but in this case a model from the **scikit-learn** library will be used. Also it is important to notice that an ANN with no hidde layers would be basically a multi regression problem, for that reason the LogisticRegressioCV module would be used.

# %%
from sklearn.linear_model import LogisticRegressionCV

#Some hyperparamaters:
fit_inter = True #this is the Bias parameter
max_iterations = 1000 #this is the number of epochs
initial_weights = 'balanced'

snn = LogisticRegressionCV(cv=5, 
                           fit_intercept = fit_inter,
                           max_iter = max_iterations, 
                           solver='lbfgs',
                           class_weight = initial_weights,
                           random_state=0).fit(X_train_sm, y_train_sm)
# Out:
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\ly266e\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#Testing of the data
y_snn_pred = snn.predict(X_test)

# %%
# Generate an accuracy Score
from sklearn.metrics import accuracy_score
snn_accuracy = accuracy_score(y_test, y_snn_pred)*100
print("Simple Neural Network (no hidden layers) accuracy: {}%".format(snn_accuracy))
# Out:
# Simple Neural Network (no hidden layers) accuracy: 69.85645933014354%

# %% [markdown]
# As we can see from the noted results, a simple neural network model provided a fairly good Accuracy value. Compared with the previous models from Milestone 02: `Decision Tree`, `Random Forest` & `SVC` this model was not able to obtain the high Accuracy values from previous analysis.

# %% [markdown]
# ### Small comparison with model from scratch from Assignment 08

# %%
# Creating a numerically stable logistic s-shaped definition to call
def sigmoid(x):
    x = np.clip(x, -500, 500)
    if x.any()>=0:
        return 1/(1 + np.exp(-x))
    else:
        return np.exp(x)/(1 + np.exp(x))
    
# define the dimentions and set the weights to random numbers
def init_parameters(dim1, dim2,std=1e-1, random = True):
    if(random):
        return(np.random.random([dim1,dim2])*std)
    else:
        return(np.zeros([dim1,dim2]))
    
# Single layer network: Forward Prop
def fwd_prop(W1,bias,X):
    Z1 = np.dot(W1,X) + bias# dot product of the weights and X + bias
    A1 = sigmoid(Z1)# Uses sigmoid to create a predicted vector
    return(A1)

#Single layer network: Backprop
def back_prop(A1,W1,bias,X,Y):
    m = np.shape(X)[1] # used the calculate the cost by the number of inputs -1/m
    # Cross entropy loss function
    cost = (-1/m)*np.sum(Y*np.log(A1) + (1-Y)*np.log(1-A1))# cost of error
    dZ1 = A1 - Y# subtract actual from pred weights
    dW1 = (1/m) * np.dot(dZ1, X.T)# calc new weight vector
    dBias = (1/m) * np.sum(dZ1, axis = 1, keepdims = True)# calc new bias vector
    grads ={"dW1": dW1, "dB1":dBias}# Weight and bias vectors after backprop
    return(grads,cost)

def run_grad_desc(num_epochs,learning_rate,X,Y,n_1):
    n_0, m = np.shape(X)
    W1 = init_parameters(n_1, n_0, True)
    B1 = init_parameters(n_1,1, True)
    loss_array = np.ones([num_epochs])*np.nan# resets the loss_array to NaNs
    for i in np.arange(num_epochs):
        A1 = fwd_prop(W1,B1,X)# get predicted vector
        grads,cost = back_prop(A1,W1,B1,X,Y)# get gradient and the cost from BP 
        W1 = W1 - learning_rate*grads["dW1"]# update weight vector LR*gradient*[BP weights]
        B1 = B1 - learning_rate*grads["dB1"]# update bias LR*gradient[BP bias]
        loss_array[i] = cost# loss array gets cross ent values
        parameter = {"W1":W1,"B1":B1}# assign 
    return(parameter,loss_array, A1)

# %%
#Getting the variables in the right format for the model from scratch
#Training Data
y_train_sm_df = pd.DataFrame(y_train_sm)
X_train_sm_df = pd.DataFrame(X_train_sm)
X = np.array(X_train_sm_df)
X = X.T
Y = np.array(y_train_sm_df)

#Testing Data
y_test_df = pd.DataFrame(y_test)
X_test_df = pd.DataFrame(X_test)
K = np.array(X_test_df)
K = K.T
L = np.array(y_test_df)

# %%
#Model with no hidden layers
num_epochs = 1000
learning_rate = 0.01
params, loss_array, prediction = run_grad_desc(num_epochs,
                                               learning_rate,
                                               X, 
                                               Y,
                                               n_1= 1)

# %%
prediction_test = fwd_prop(params['W1'][:len(L)],params['B1'][:len(L)],K)

# %%
delta = []
test_pred = prediction_test[1]
for i in range(len(prediction_test[1])):
    d = abs(test_pred[i] - L[i])
    delta.append(d)

total_delta = sum(delta)
nn0_accuracy = (1 - total_delta[0]/len(L))*100
print('Accuracy: ' + str(nn0_accuracy) + '%')
# Out:
# Accuracy: 92.17834342996937%

# %% [markdown]
# Doing a quick comparison (not really an exhaustive comparison) it seems to be that with 1000 Epochs the model from scratch simulating a simple neural network with no hidden layers and just 1 preceptor get us to a better Accuracy value on the testing data set, from 69% to 92%.

# %% [markdown]
# ## Deep Neural Network Model

# %% [markdown]
# ### Scikit Learn

# %%
from sklearn.neural_network import MLPClassifier

#Some hyperparamaters:
hidden = 50
act = 'relu'
opt = 'adam'
lr = 'adaptive'
lr_value = 0.01
epoch = 1000

dnn = MLPClassifier(hidden_layer_sizes = hidden,
                    activation = act,
                    solver = opt,
                    learning_rate = lr,
                    learning_rate_init = lr_value,
                    max_iter = epoch,
                    random_state=1).fit(X_train_sm, y_train_sm)

# %%
#Testing of the data
y_dnn_pred = dnn.predict(X_test)

# %%
dnn_accuracy = accuracy_score(y_test, y_dnn_pred)*100
print("Deep Neural Network accuracy: {}%".format(dnn_accuracy))
# Out:
# Deep Neural Network accuracy: 88.27751196172248%

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# %%
#Simple Deep Neural Network will be presented here
model = keras.Sequential([
    #keras.layers.Dense(100, activation='relu'), 
    keras.layers.Dense(100, input_dim = 50, activation='relu'), 
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='sgd', 
              loss='binary_crossentropy',
              metrics=['BinaryAccuracy'])

# %%
model.fit(X_train_sm, y_train_sm, epochs=1000)
# Out:
# Epoch 1/1000
# 57/57 [==============================] - 1s 944us/step - loss: 0.6924 - binary_accuracy: 0.5173
# Epoch 2/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6894 - binary_accuracy: 0.5554
# Epoch 3/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6884 - binary_accuracy: 0.5826
# Epoch 4/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.6871 - binary_accuracy: 0.5852
# Epoch 5/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6880 - binary_accuracy: 0.5739
# Epoch 6/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6852 - binary_accuracy: 0.6077
# Epoch 7/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6864 - binary_accuracy: 0.5783
# Epoch 8/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6848 - binary_accuracy: 0.5899
# Epoch 9/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6838 - binary_accuracy: 0.5863
# Epoch 10/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.6822 - binary_accuracy: 0.5865
# Epoch 11/1000
# 57/57 [==============================] - 0s 945us/step - loss: 0.6837 - binary_accuracy: 0.5929
# Epoch 12/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6800 - binary_accuracy: 0.6182
# Epoch 13/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6804 - binary_accuracy: 0.6094
# Epoch 14/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6771 - binary_accuracy: 0.6470
# Epoch 15/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6796 - binary_accuracy: 0.6297
# Epoch 16/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6772 - binary_accuracy: 0.6152
# Epoch 17/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6783 - binary_accuracy: 0.6131
# Epoch 18/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6769 - binary_accuracy: 0.6119
# Epoch 19/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6798 - binary_accuracy: 0.6156
# Epoch 20/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6757 - binary_accuracy: 0.6208
# Epoch 21/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6748 - binary_accuracy: 0.6318
# Epoch 22/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6723 - binary_accuracy: 0.6416
# Epoch 23/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6745 - binary_accuracy: 0.6154
# Epoch 24/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6758 - binary_accuracy: 0.5935
# Epoch 25/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.6712 - binary_accuracy: 0.6284
# Epoch 26/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6708 - binary_accuracy: 0.6355
# Epoch 27/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6704 - binary_accuracy: 0.6403
# Epoch 28/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6659 - binary_accuracy: 0.6521
# Epoch 29/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.6725 - binary_accuracy: 0.6176
# Epoch 30/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6622 - binary_accuracy: 0.6666
# Epoch 31/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6664 - binary_accuracy: 0.6389
# Epoch 32/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6667 - binary_accuracy: 0.6366
# Epoch 33/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6664 - binary_accuracy: 0.6308
# Epoch 34/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6668 - binary_accuracy: 0.6422
# Epoch 35/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6614 - binary_accuracy: 0.6471
# Epoch 36/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6635 - binary_accuracy: 0.6471
# Epoch 37/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.6559 - binary_accuracy: 0.6677
# Epoch 38/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.6615 - binary_accuracy: 0.6589
# Epoch 39/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6587 - binary_accuracy: 0.6565
# Epoch 40/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6590 - binary_accuracy: 0.6364
# Epoch 41/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6587 - binary_accuracy: 0.6526
# Epoch 42/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.6594 - binary_accuracy: 0.6418
# Epoch 43/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6491 - binary_accuracy: 0.6713
# Epoch 44/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.6552 - binary_accuracy: 0.6510
# Epoch 45/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6489 - binary_accuracy: 0.6584
# Epoch 46/1000
# 57/57 [==============================] - 0s 943us/step - loss: 0.6551 - binary_accuracy: 0.6532
# Epoch 47/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6528 - binary_accuracy: 0.6554
# Epoch 48/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6527 - binary_accuracy: 0.6540
# Epoch 49/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6504 - binary_accuracy: 0.6524
# Epoch 50/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6548 - binary_accuracy: 0.6402
# Epoch 51/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6474 - binary_accuracy: 0.6618
# Epoch 52/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6489 - binary_accuracy: 0.6524
# Epoch 53/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6439 - binary_accuracy: 0.6701
# Epoch 54/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6500 - binary_accuracy: 0.6465
# Epoch 55/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.6454 - binary_accuracy: 0.6405
# Epoch 56/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6402 - binary_accuracy: 0.6644
# Epoch 57/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6368 - binary_accuracy: 0.6740
# Epoch 58/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6386 - binary_accuracy: 0.6578
# Epoch 59/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6417 - binary_accuracy: 0.6661
# Epoch 60/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6356 - binary_accuracy: 0.6657
# Epoch 61/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6412 - binary_accuracy: 0.6573
# Epoch 62/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6350 - binary_accuracy: 0.6733
# Epoch 63/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.6306 - binary_accuracy: 0.6674
# Epoch 64/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.6339 - binary_accuracy: 0.6640
# Epoch 65/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6411 - binary_accuracy: 0.6447
# Epoch 66/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6247 - binary_accuracy: 0.6802
# Epoch 67/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6317 - binary_accuracy: 0.6724
# Epoch 68/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6379 - binary_accuracy: 0.6495
# Epoch 69/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6247 - binary_accuracy: 0.6804
# Epoch 70/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6195 - binary_accuracy: 0.6868
# Epoch 71/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6267 - binary_accuracy: 0.6888
# Epoch 72/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6210 - binary_accuracy: 0.6905
# Epoch 73/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6223 - binary_accuracy: 0.6750
# Epoch 74/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6326 - binary_accuracy: 0.6525
# Epoch 75/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6242 - binary_accuracy: 0.6812
# Epoch 76/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6269 - binary_accuracy: 0.6643
# Epoch 77/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6248 - binary_accuracy: 0.6735
# Epoch 78/1000
# 57/57 [==============================] - 0s 908us/step - loss: 0.6155 - binary_accuracy: 0.6842
# Epoch 79/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6156 - binary_accuracy: 0.6839
# Epoch 80/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6237 - binary_accuracy: 0.6685
# Epoch 81/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6078 - binary_accuracy: 0.6838
# Epoch 82/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6081 - binary_accuracy: 0.6850
# Epoch 83/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6076 - binary_accuracy: 0.6944 0s - loss: 0.6073 - binary_accuracy: 0.694
# Epoch 84/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.6143 - binary_accuracy: 0.6863
# Epoch 85/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6043 - binary_accuracy: 0.7115
# Epoch 86/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6042 - binary_accuracy: 0.7037
# Epoch 87/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6086 - binary_accuracy: 0.6842
# Epoch 88/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.6128 - binary_accuracy: 0.6794
# Epoch 89/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6053 - binary_accuracy: 0.6898
# Epoch 90/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6079 - binary_accuracy: 0.6846
# Epoch 91/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6056 - binary_accuracy: 0.6966
# Epoch 92/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.6068 - binary_accuracy: 0.6841
# Epoch 93/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.6051 - binary_accuracy: 0.6896
# Epoch 94/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6040 - binary_accuracy: 0.6955
# Epoch 95/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.5884 - binary_accuracy: 0.7115
# Epoch 96/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.5990 - binary_accuracy: 0.6958
# Epoch 97/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5927 - binary_accuracy: 0.6988
# Epoch 98/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.5905 - binary_accuracy: 0.6928
# Epoch 99/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5914 - binary_accuracy: 0.6988
# Epoch 100/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5883 - binary_accuracy: 0.7096
# Epoch 101/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.6030 - binary_accuracy: 0.6744
# Epoch 102/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5858 - binary_accuracy: 0.6919
# Epoch 103/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5800 - binary_accuracy: 0.7114
# Epoch 104/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5837 - binary_accuracy: 0.7179
# Epoch 105/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5809 - binary_accuracy: 0.7171
# Epoch 106/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5828 - binary_accuracy: 0.7155
# Epoch 107/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5803 - binary_accuracy: 0.7149
# Epoch 108/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5825 - binary_accuracy: 0.7128
# Epoch 109/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.5839 - binary_accuracy: 0.7085
# Epoch 110/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.5653 - binary_accuracy: 0.7353
# Epoch 111/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5600 - binary_accuracy: 0.7267
# Epoch 112/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5835 - binary_accuracy: 0.7058
# Epoch 113/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.5739 - binary_accuracy: 0.7197
# Epoch 114/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.5672 - binary_accuracy: 0.7327
# Epoch 115/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5778 - binary_accuracy: 0.7155
# Epoch 116/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.5736 - binary_accuracy: 0.7173
# Epoch 117/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5768 - binary_accuracy: 0.7198
# Epoch 118/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5792 - binary_accuracy: 0.6883
# Epoch 119/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5668 - binary_accuracy: 0.7263
# Epoch 120/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.5619 - binary_accuracy: 0.7210
# Epoch 121/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5719 - binary_accuracy: 0.7137
# Epoch 122/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5630 - binary_accuracy: 0.7254
# Epoch 123/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5689 - binary_accuracy: 0.7052
# Epoch 124/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5464 - binary_accuracy: 0.7529
# Epoch 125/1000
# 57/57 [==============================] - 0s 837us/step - loss: 0.5614 - binary_accuracy: 0.7290
# Epoch 126/1000
# 57/57 [==============================] - 0s 784us/step - loss: 0.5616 - binary_accuracy: 0.7158
# Epoch 127/1000
# 57/57 [==============================] - 0s 819us/step - loss: 0.5570 - binary_accuracy: 0.7237
# Epoch 128/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.5635 - binary_accuracy: 0.7207
# Epoch 129/1000
# 57/57 [==============================] - 0s 784us/step - loss: 0.5467 - binary_accuracy: 0.7296
# Epoch 130/1000
# 57/57 [==============================] - 0s 784us/step - loss: 0.5501 - binary_accuracy: 0.7380
# Epoch 131/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.5526 - binary_accuracy: 0.7332
# Epoch 132/1000
# 57/57 [==============================] - 0s 819us/step - loss: 0.5422 - binary_accuracy: 0.7377
# Epoch 133/1000
# 57/57 [==============================] - 0s 837us/step - loss: 0.5479 - binary_accuracy: 0.7280
# Epoch 134/1000
# 57/57 [==============================] - 0s 838us/step - loss: 0.5537 - binary_accuracy: 0.7422
# Epoch 135/1000
# 57/57 [==============================] - 0s 855us/step - loss: 0.5605 - binary_accuracy: 0.7303
# Epoch 136/1000
# 57/57 [==============================] - 0s 838us/step - loss: 0.5509 - binary_accuracy: 0.7214
# Epoch 137/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5426 - binary_accuracy: 0.7369
# Epoch 138/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5553 - binary_accuracy: 0.7284
# Epoch 139/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5497 - binary_accuracy: 0.7344
# Epoch 140/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5517 - binary_accuracy: 0.7359
# Epoch 141/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5471 - binary_accuracy: 0.7371
# Epoch 142/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5453 - binary_accuracy: 0.7353
# Epoch 143/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5511 - binary_accuracy: 0.7254
# Epoch 144/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5451 - binary_accuracy: 0.7355
# Epoch 145/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5376 - binary_accuracy: 0.7454
# Epoch 146/1000
# 57/57 [==============================] - ETA: 0s - loss: 0.5469 - binary_accuracy: 0.742 - 0s 1ms/step - loss: 0.5451 - binary_accuracy: 0.7430
# Epoch 147/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5309 - binary_accuracy: 0.7474
# Epoch 148/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5236 - binary_accuracy: 0.7469
# Epoch 149/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5246 - binary_accuracy: 0.7556
# Epoch 150/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.5365 - binary_accuracy: 0.7284
# Epoch 151/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5205 - binary_accuracy: 0.7695
# Epoch 152/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5286 - binary_accuracy: 0.7657
# Epoch 153/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5269 - binary_accuracy: 0.7413
# Epoch 154/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5237 - binary_accuracy: 0.7493
# Epoch 155/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5238 - binary_accuracy: 0.7399
# Epoch 156/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5202 - binary_accuracy: 0.7534
# Epoch 157/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5198 - binary_accuracy: 0.7431
# Epoch 158/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5257 - binary_accuracy: 0.7494
# Epoch 159/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.5173 - binary_accuracy: 0.7564
# Epoch 160/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5267 - binary_accuracy: 0.7342
# Epoch 161/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5144 - binary_accuracy: 0.7412
# Epoch 162/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5336 - binary_accuracy: 0.7315
# Epoch 163/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5040 - binary_accuracy: 0.7566
# Epoch 164/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.5299 - binary_accuracy: 0.7297
# Epoch 165/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5181 - binary_accuracy: 0.7418
# Epoch 166/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.5002 - binary_accuracy: 0.7636
# Epoch 167/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5104 - binary_accuracy: 0.7616
# Epoch 168/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5047 - binary_accuracy: 0.7661
# Epoch 169/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5112 - binary_accuracy: 0.7619
# Epoch 170/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5115 - binary_accuracy: 0.7485
# Epoch 171/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.5171 - binary_accuracy: 0.7482
# Epoch 172/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.5054 - binary_accuracy: 0.7617
# Epoch 173/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.5076 - binary_accuracy: 0.7538
# Epoch 174/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.5045 - binary_accuracy: 0.7539
# Epoch 175/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5030 - binary_accuracy: 0.7624
# Epoch 176/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.4909 - binary_accuracy: 0.7695
# Epoch 177/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.5010 - binary_accuracy: 0.7532
# Epoch 178/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.5047 - binary_accuracy: 0.7593
# Epoch 179/1000
# 57/57 [==============================] - 0s 837us/step - loss: 0.4977 - binary_accuracy: 0.7660
# Epoch 180/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.4863 - binary_accuracy: 0.7690
# Epoch 181/1000
# 57/57 [==============================] - 0s 784us/step - loss: 0.4866 - binary_accuracy: 0.7633
# Epoch 182/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4963 - binary_accuracy: 0.7680
# Epoch 183/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.5005 - binary_accuracy: 0.7493
# Epoch 184/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4942 - binary_accuracy: 0.7705
# Epoch 185/1000
# 57/57 [==============================] - 0s 837us/step - loss: 0.4991 - binary_accuracy: 0.7423
# Epoch 186/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.4935 - binary_accuracy: 0.7616
# Epoch 187/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.4861 - binary_accuracy: 0.7797
# Epoch 188/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4797 - binary_accuracy: 0.7609
# Epoch 189/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4689 - binary_accuracy: 0.7880
# Epoch 190/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4775 - binary_accuracy: 0.7827
# Epoch 191/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4689 - binary_accuracy: 0.7730
# Epoch 192/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.4883 - binary_accuracy: 0.7708
# Epoch 193/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4834 - binary_accuracy: 0.7788
# Epoch 194/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4916 - binary_accuracy: 0.7758
# Epoch 195/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4883 - binary_accuracy: 0.7648
# Epoch 196/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4836 - binary_accuracy: 0.7638
# Epoch 197/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4854 - binary_accuracy: 0.7761
# Epoch 198/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4702 - binary_accuracy: 0.7777
# Epoch 199/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4753 - binary_accuracy: 0.7728
# Epoch 200/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4843 - binary_accuracy: 0.7724
# Epoch 201/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4785 - binary_accuracy: 0.7618
# Epoch 202/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.4787 - binary_accuracy: 0.7798
# Epoch 203/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4622 - binary_accuracy: 0.7853
# Epoch 204/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.4772 - binary_accuracy: 0.7806
# Epoch 205/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.4785 - binary_accuracy: 0.7771
# Epoch 206/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.4577 - binary_accuracy: 0.7901
# Epoch 207/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4608 - binary_accuracy: 0.7984
# Epoch 208/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4681 - binary_accuracy: 0.7778
# Epoch 209/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4675 - binary_accuracy: 0.7830
# Epoch 210/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.4403 - binary_accuracy: 0.8065
# Epoch 211/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.4712 - binary_accuracy: 0.7811
# Epoch 212/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4466 - binary_accuracy: 0.7917
# Epoch 213/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4556 - binary_accuracy: 0.7910
# Epoch 214/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.4551 - binary_accuracy: 0.7905
# Epoch 215/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.4408 - binary_accuracy: 0.8004
# Epoch 216/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.4632 - binary_accuracy: 0.7864
# Epoch 217/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4569 - binary_accuracy: 0.7850
# Epoch 218/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.4556 - binary_accuracy: 0.7919
# Epoch 219/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4762 - binary_accuracy: 0.7830
# Epoch 220/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.4680 - binary_accuracy: 0.7828
# Epoch 221/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4622 - binary_accuracy: 0.7965
# Epoch 222/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.4526 - binary_accuracy: 0.7977
# Epoch 223/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.4399 - binary_accuracy: 0.8039
# Epoch 224/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4443 - binary_accuracy: 0.7941
# Epoch 225/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4555 - binary_accuracy: 0.7766
# Epoch 226/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4442 - binary_accuracy: 0.8033
# Epoch 227/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.4374 - binary_accuracy: 0.8097
# Epoch 228/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.4361 - binary_accuracy: 0.8014
# Epoch 229/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4460 - binary_accuracy: 0.8053
# Epoch 230/1000
# 57/57 [==============================] - 0s 927us/step - loss: 0.4235 - binary_accuracy: 0.8078
# Epoch 231/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4231 - binary_accuracy: 0.8081
# Epoch 232/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4258 - binary_accuracy: 0.8187
# Epoch 233/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4396 - binary_accuracy: 0.8039
# Epoch 234/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.4296 - binary_accuracy: 0.8101
# Epoch 235/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4618 - binary_accuracy: 0.7776
# Epoch 236/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4321 - binary_accuracy: 0.8191
# Epoch 237/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.4228 - binary_accuracy: 0.8184
# Epoch 238/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4378 - binary_accuracy: 0.8017
# Epoch 239/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4112 - binary_accuracy: 0.8195
# Epoch 240/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.4143 - binary_accuracy: 0.8255
# Epoch 241/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4274 - binary_accuracy: 0.8135
# Epoch 242/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.4343 - binary_accuracy: 0.8025
# Epoch 243/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4251 - binary_accuracy: 0.8152
# Epoch 244/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4186 - binary_accuracy: 0.8229
# Epoch 245/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4425 - binary_accuracy: 0.8033
# Epoch 246/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4205 - binary_accuracy: 0.8068
# Epoch 247/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4091 - binary_accuracy: 0.8240
# Epoch 248/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.3975 - binary_accuracy: 0.8230
# Epoch 249/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4139 - binary_accuracy: 0.8200
# Epoch 250/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4043 - binary_accuracy: 0.8243
# Epoch 251/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3970 - binary_accuracy: 0.8349
# Epoch 252/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4125 - binary_accuracy: 0.8094
# Epoch 253/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.4040 - binary_accuracy: 0.8255
# Epoch 254/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4005 - binary_accuracy: 0.8209
# Epoch 255/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4327 - binary_accuracy: 0.7986
# Epoch 256/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4127 - binary_accuracy: 0.8129
# Epoch 257/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4040 - binary_accuracy: 0.8308
# Epoch 258/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3927 - binary_accuracy: 0.8418
# Epoch 259/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.4025 - binary_accuracy: 0.8270
# Epoch 260/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3950 - binary_accuracy: 0.8304
# Epoch 261/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4011 - binary_accuracy: 0.8270
# Epoch 262/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3882 - binary_accuracy: 0.8365
# Epoch 263/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3892 - binary_accuracy: 0.8471
# Epoch 264/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3734 - binary_accuracy: 0.8461
# Epoch 265/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.4126 - binary_accuracy: 0.8233
# Epoch 266/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3990 - binary_accuracy: 0.8255
# Epoch 267/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3671 - binary_accuracy: 0.8597
# Epoch 268/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3778 - binary_accuracy: 0.8503
# Epoch 269/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3843 - binary_accuracy: 0.8384
# Epoch 270/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3818 - binary_accuracy: 0.8453
# Epoch 271/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3699 - binary_accuracy: 0.8492
# Epoch 272/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.3719 - binary_accuracy: 0.8388
# Epoch 273/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.4122 - binary_accuracy: 0.8244
# Epoch 274/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3778 - binary_accuracy: 0.8483
# Epoch 275/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3650 - binary_accuracy: 0.8612
# Epoch 276/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.3727 - binary_accuracy: 0.8496
# Epoch 277/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.3962 - binary_accuracy: 0.8126
# Epoch 278/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3880 - binary_accuracy: 0.8327
# Epoch 279/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3798 - binary_accuracy: 0.8536
# Epoch 280/1000
# 57/57 [==============================] - 0s 925us/step - loss: 0.3773 - binary_accuracy: 0.8482
# Epoch 281/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.3754 - binary_accuracy: 0.8447
# Epoch 282/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3668 - binary_accuracy: 0.8550
# Epoch 283/1000
# 57/57 [==============================] - 0s 855us/step - loss: 0.3770 - binary_accuracy: 0.8280
# Epoch 284/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3499 - binary_accuracy: 0.8623
# Epoch 285/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3662 - binary_accuracy: 0.8422
# Epoch 286/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3701 - binary_accuracy: 0.8549
# Epoch 287/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3622 - binary_accuracy: 0.8475
# Epoch 288/1000
# 57/57 [==============================] - 0s 908us/step - loss: 0.3734 - binary_accuracy: 0.8312
# Epoch 289/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3642 - binary_accuracy: 0.8442
# Epoch 290/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3552 - binary_accuracy: 0.8580
# Epoch 291/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3569 - binary_accuracy: 0.8605
# Epoch 292/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3535 - binary_accuracy: 0.8625
# Epoch 293/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3449 - binary_accuracy: 0.8633
# Epoch 294/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3549 - binary_accuracy: 0.8445
# Epoch 295/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.3927 - binary_accuracy: 0.8200
# Epoch 296/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3479 - binary_accuracy: 0.8617
# Epoch 297/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3666 - binary_accuracy: 0.8439
# Epoch 298/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3693 - binary_accuracy: 0.8456
# Epoch 299/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3274 - binary_accuracy: 0.8729
# Epoch 300/1000
# 57/57 [==============================] - 0s 925us/step - loss: 0.3666 - binary_accuracy: 0.8375
# Epoch 301/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3534 - binary_accuracy: 0.8458
# Epoch 302/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3553 - binary_accuracy: 0.8582
# Epoch 303/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3422 - binary_accuracy: 0.8648
# Epoch 304/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3668 - binary_accuracy: 0.8534
# Epoch 305/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3746 - binary_accuracy: 0.8376
# Epoch 306/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3625 - binary_accuracy: 0.8544
# Epoch 307/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3459 - binary_accuracy: 0.8646
# Epoch 308/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3916 - binary_accuracy: 0.8253
# Epoch 309/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.3607 - binary_accuracy: 0.8297
# Epoch 310/1000
# 57/57 [==============================] - 0s 872us/step - loss: 0.3078 - binary_accuracy: 0.8906
# Epoch 311/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.3315 - binary_accuracy: 0.8658
# Epoch 312/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.3361 - binary_accuracy: 0.8776
# Epoch 313/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3235 - binary_accuracy: 0.8808
# Epoch 314/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3807 - binary_accuracy: 0.8493
# Epoch 315/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3107 - binary_accuracy: 0.8731
# Epoch 316/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3939 - binary_accuracy: 0.8249
# Epoch 317/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.3437 - binary_accuracy: 0.8613
# Epoch 318/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3675 - binary_accuracy: 0.8386
# Epoch 319/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.3189 - binary_accuracy: 0.8806
# Epoch 320/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3189 - binary_accuracy: 0.8787
# Epoch 321/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3201 - binary_accuracy: 0.8730
# Epoch 322/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3415 - binary_accuracy: 0.8644
# Epoch 323/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.3019 - binary_accuracy: 0.8843
# Epoch 324/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3313 - binary_accuracy: 0.8585
# Epoch 325/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3153 - binary_accuracy: 0.8826
# Epoch 326/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3164 - binary_accuracy: 0.8697
# Epoch 327/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3280 - binary_accuracy: 0.8665
# Epoch 328/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3154 - binary_accuracy: 0.8784
# Epoch 329/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3202 - binary_accuracy: 0.8786
# Epoch 330/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.3378 - binary_accuracy: 0.8536
# Epoch 331/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3008 - binary_accuracy: 0.8785
# Epoch 332/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3028 - binary_accuracy: 0.8823
# Epoch 333/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3021 - binary_accuracy: 0.8856
# Epoch 334/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3118 - binary_accuracy: 0.8778
# Epoch 335/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3106 - binary_accuracy: 0.8761
# Epoch 336/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3192 - binary_accuracy: 0.8626
# Epoch 337/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3300 - binary_accuracy: 0.8602
# Epoch 338/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3257 - binary_accuracy: 0.8704
# Epoch 339/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3286 - binary_accuracy: 0.8628
# Epoch 340/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3208 - binary_accuracy: 0.8617
# Epoch 341/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3158 - binary_accuracy: 0.8740
# Epoch 342/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3462 - binary_accuracy: 0.8548
# Epoch 343/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.2969 - binary_accuracy: 0.8728
# Epoch 344/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3001 - binary_accuracy: 0.8863
# Epoch 345/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.2763 - binary_accuracy: 0.9027
# Epoch 346/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3122 - binary_accuracy: 0.8752
# Epoch 347/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.3206 - binary_accuracy: 0.8624
# Epoch 348/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2879 - binary_accuracy: 0.8992
# Epoch 349/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3014 - binary_accuracy: 0.8849
# Epoch 350/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3005 - binary_accuracy: 0.8865
# Epoch 351/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.2810 - binary_accuracy: 0.8891
# Epoch 352/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.2798 - binary_accuracy: 0.9038
# Epoch 353/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2910 - binary_accuracy: 0.8824
# Epoch 354/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3060 - binary_accuracy: 0.8866
# Epoch 355/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2877 - binary_accuracy: 0.8933
# Epoch 356/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.2722 - binary_accuracy: 0.9031
# Epoch 357/1000
# 57/57 [==============================] - 0s 801us/step - loss: 0.2914 - binary_accuracy: 0.8839
# Epoch 358/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.3001 - binary_accuracy: 0.8808
# Epoch 359/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.2849 - binary_accuracy: 0.8924
# Epoch 360/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2944 - binary_accuracy: 0.8847
# Epoch 361/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.3046 - binary_accuracy: 0.8771
# Epoch 362/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3013 - binary_accuracy: 0.8796
# Epoch 363/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.2849 - binary_accuracy: 0.8851
# Epoch 364/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.2733 - binary_accuracy: 0.8971
# Epoch 365/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.3171 - binary_accuracy: 0.8697
# Epoch 366/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3272 - binary_accuracy: 0.8644
# Epoch 367/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2868 - binary_accuracy: 0.8882
# Epoch 368/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2691 - binary_accuracy: 0.9033
# Epoch 369/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2935 - binary_accuracy: 0.8911
# Epoch 370/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2751 - binary_accuracy: 0.8840
# Epoch 371/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2761 - binary_accuracy: 0.8856
# Epoch 372/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2573 - binary_accuracy: 0.9032
# Epoch 373/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2908 - binary_accuracy: 0.8845
# Epoch 374/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3026 - binary_accuracy: 0.8764
# Epoch 375/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2668 - binary_accuracy: 0.9098
# Epoch 376/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2751 - binary_accuracy: 0.8934
# Epoch 377/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2686 - binary_accuracy: 0.9060
# Epoch 378/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2656 - binary_accuracy: 0.8899
# Epoch 379/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2896 - binary_accuracy: 0.8797
# Epoch 380/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2751 - binary_accuracy: 0.8976
# Epoch 381/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2463 - binary_accuracy: 0.9138
# Epoch 382/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2878 - binary_accuracy: 0.8667
# Epoch 383/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2503 - binary_accuracy: 0.9043
# Epoch 384/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2564 - binary_accuracy: 0.9061
# Epoch 385/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2603 - binary_accuracy: 0.9044
# Epoch 386/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3180 - binary_accuracy: 0.8654
# Epoch 387/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.3292 - binary_accuracy: 0.8614
# Epoch 388/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2331 - binary_accuracy: 0.9192
# Epoch 389/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2530 - binary_accuracy: 0.9102
# Epoch 390/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2529 - binary_accuracy: 0.9075
# Epoch 391/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2651 - binary_accuracy: 0.9024
# Epoch 392/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2463 - binary_accuracy: 0.9005
# Epoch 393/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2489 - binary_accuracy: 0.9180
# Epoch 394/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2658 - binary_accuracy: 0.9011
# Epoch 395/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2647 - binary_accuracy: 0.8998
# Epoch 396/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2513 - binary_accuracy: 0.9105
# Epoch 397/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.2348 - binary_accuracy: 0.9214
# Epoch 398/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2302 - binary_accuracy: 0.9191
# Epoch 399/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.2614 - binary_accuracy: 0.9023
# Epoch 400/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2427 - binary_accuracy: 0.9161
# Epoch 401/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2338 - binary_accuracy: 0.9199
# Epoch 402/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2656 - binary_accuracy: 0.8965
# Epoch 403/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2247 - binary_accuracy: 0.9287
# Epoch 404/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2276 - binary_accuracy: 0.9193
# Epoch 405/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2927 - binary_accuracy: 0.8786
# Epoch 406/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2491 - binary_accuracy: 0.9060
# Epoch 407/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2557 - binary_accuracy: 0.8918
# Epoch 408/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2512 - binary_accuracy: 0.8981
# Epoch 409/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2343 - binary_accuracy: 0.9152 0s - loss: 0.2336 - binary_accuracy: 0.915
# Epoch 410/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2505 - binary_accuracy: 0.9000
# Epoch 411/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2418 - binary_accuracy: 0.9047
# Epoch 412/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2482 - binary_accuracy: 0.9065
# Epoch 413/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.3190 - binary_accuracy: 0.8625
# Epoch 414/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2411 - binary_accuracy: 0.9140
# Epoch 415/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2446 - binary_accuracy: 0.9011
# Epoch 416/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2326 - binary_accuracy: 0.9068
# Epoch 417/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2713 - binary_accuracy: 0.8902
# Epoch 418/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2423 - binary_accuracy: 0.9039
# Epoch 419/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2355 - binary_accuracy: 0.9101
# Epoch 420/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2496 - binary_accuracy: 0.9056
# Epoch 421/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2626 - binary_accuracy: 0.8917
# Epoch 422/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.2997 - binary_accuracy: 0.8716
# Epoch 423/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2551 - binary_accuracy: 0.9025
# Epoch 424/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.2090 - binary_accuracy: 0.9301
# Epoch 425/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2140 - binary_accuracy: 0.9289
# Epoch 426/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2313 - binary_accuracy: 0.9150
# Epoch 427/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.3114 - binary_accuracy: 0.8640
# Epoch 428/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2283 - binary_accuracy: 0.9124
# Epoch 429/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2289 - binary_accuracy: 0.9115
# Epoch 430/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.2203 - binary_accuracy: 0.9264
# Epoch 431/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.2315 - binary_accuracy: 0.9064
# Epoch 432/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2367 - binary_accuracy: 0.9136
# Epoch 433/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2242 - binary_accuracy: 0.9211
# Epoch 434/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.2105 - binary_accuracy: 0.9252
# Epoch 435/1000
# ...
# Epoch 856/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0541 - binary_accuracy: 0.9865
# Epoch 857/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0517 - binary_accuracy: 0.9888
# Epoch 858/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0483 - binary_accuracy: 0.9912
# Epoch 859/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0538 - binary_accuracy: 0.9865
# Epoch 860/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0519 - binary_accuracy: 0.9867
# Epoch 861/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0444 - binary_accuracy: 0.9947
# Epoch 862/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0402 - binary_accuracy: 0.9944
# Epoch 863/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0421 - binary_accuracy: 0.9922
# Epoch 864/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1613 - binary_accuracy: 0.9498
# Epoch 865/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0596 - binary_accuracy: 0.9869
# Epoch 866/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.3208 - binary_accuracy: 0.9187
# Epoch 867/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.0524 - binary_accuracy: 0.9863
# Epoch 868/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0432 - binary_accuracy: 0.9917
# Epoch 869/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0374 - binary_accuracy: 0.9930
# Epoch 870/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0419 - binary_accuracy: 0.9917
# Epoch 871/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0436 - binary_accuracy: 0.9868
# Epoch 872/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0440 - binary_accuracy: 0.9968
# Epoch 873/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0415 - binary_accuracy: 0.9939
# Epoch 874/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0455 - binary_accuracy: 0.9908
# Epoch 875/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0446 - binary_accuracy: 0.9930
# Epoch 876/1000
# 57/57 [==============================] - 0s 908us/step - loss: 0.0652 - binary_accuracy: 0.9792
# Epoch 877/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0360 - binary_accuracy: 0.9963
# Epoch 878/1000
# 57/57 [==============================] - 0s 908us/step - loss: 0.0407 - binary_accuracy: 0.9930
# Epoch 879/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.0528 - binary_accuracy: 0.9875
# Epoch 880/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0427 - binary_accuracy: 0.9936
# Epoch 881/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0515 - binary_accuracy: 0.9870
# Epoch 882/1000
# 57/57 [==============================] - 0s 855us/step - loss: 0.0581 - binary_accuracy: 0.9813
# Epoch 883/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0304 - binary_accuracy: 0.9963
# Epoch 884/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.0383 - binary_accuracy: 0.9953
# Epoch 885/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0403 - binary_accuracy: 0.9961
# Epoch 886/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0587 - binary_accuracy: 0.9863
# Epoch 887/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0425 - binary_accuracy: 0.9885
# Epoch 888/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0414 - binary_accuracy: 0.9907
# Epoch 889/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0403 - binary_accuracy: 0.9945
# Epoch 890/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1254 - binary_accuracy: 0.9612
# Epoch 891/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0352 - binary_accuracy: 0.9944
# Epoch 892/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0358 - binary_accuracy: 0.9912
# Epoch 893/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0329 - binary_accuracy: 0.9966
# Epoch 894/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0381 - binary_accuracy: 0.9927
# Epoch 895/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0423 - binary_accuracy: 0.9913
# Epoch 896/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.1354 - binary_accuracy: 0.9608
# Epoch 897/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0495 - binary_accuracy: 0.9914
# Epoch 898/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0476 - binary_accuracy: 0.9870
# Epoch 899/1000
# 57/57 [==============================] - 0s 908us/step - loss: 0.0524 - binary_accuracy: 0.9880
# Epoch 900/1000
# 57/57 [==============================] - 0s 891us/step - loss: 0.0439 - binary_accuracy: 0.9905
# Epoch 901/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0411 - binary_accuracy: 0.9938
# Epoch 902/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0370 - binary_accuracy: 0.9938
# Epoch 903/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0344 - binary_accuracy: 0.9935
# Epoch 904/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.4638 - binary_accuracy: 0.8986
# Epoch 905/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0473 - binary_accuracy: 0.9912
# Epoch 906/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0430 - binary_accuracy: 0.9912
# Epoch 907/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0408 - binary_accuracy: 0.9919
# Epoch 908/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0377 - binary_accuracy: 0.9932
# Epoch 909/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0394 - binary_accuracy: 0.9948
# Epoch 910/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.0453 - binary_accuracy: 0.9838
# Epoch 911/1000
# 57/57 [==============================] - 0s 837us/step - loss: 0.0516 - binary_accuracy: 0.9852
# Epoch 912/1000
# 57/57 [==============================] - 0s 819us/step - loss: 0.0397 - binary_accuracy: 0.9894
# Epoch 913/1000
# 57/57 [==============================] - 0s 819us/step - loss: 0.0460 - binary_accuracy: 0.9921
# Epoch 914/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0405 - binary_accuracy: 0.9925
# Epoch 915/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0382 - binary_accuracy: 0.9922
# Epoch 916/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0317 - binary_accuracy: 0.9952
# Epoch 917/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0658 - binary_accuracy: 0.9821
# Epoch 918/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0684 - binary_accuracy: 0.9716
# Epoch 919/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0333 - binary_accuracy: 0.9970
# Epoch 920/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0315 - binary_accuracy: 0.9990
# Epoch 921/1000
# 57/57 [==============================] - 0s 961us/step - loss: 0.0328 - binary_accuracy: 0.9969
# Epoch 922/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0318 - binary_accuracy: 0.9946
# Epoch 923/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0284 - binary_accuracy: 0.9960
# Epoch 924/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0270 - binary_accuracy: 0.9975
# Epoch 925/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0438 - binary_accuracy: 0.9926
# Epoch 926/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0438 - binary_accuracy: 0.9868
# Epoch 927/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0331 - binary_accuracy: 0.9940
# Epoch 928/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0491 - binary_accuracy: 0.9887
# Epoch 929/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0304 - binary_accuracy: 0.9953
# Epoch 930/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.6887 - binary_accuracy: 0.8280
# Epoch 931/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0553 - binary_accuracy: 0.9857
# Epoch 932/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0788 - binary_accuracy: 0.9864
# Epoch 933/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.1031 - binary_accuracy: 0.9743
# Epoch 934/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0460 - binary_accuracy: 0.9950
# Epoch 935/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0544 - binary_accuracy: 0.9858
# Epoch 936/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.1224 - binary_accuracy: 0.9526
# Epoch 937/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0412 - binary_accuracy: 0.9924
# Epoch 938/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0471 - binary_accuracy: 0.9891
# Epoch 939/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0724 - binary_accuracy: 0.9776
# Epoch 940/1000
# 57/57 [==============================] - 0s 998us/step - loss: 0.1396 - binary_accuracy: 0.9556
# Epoch 941/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0493 - binary_accuracy: 0.9896
# Epoch 942/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0489 - binary_accuracy: 0.9924
# Epoch 943/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0507 - binary_accuracy: 0.9888
# Epoch 944/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0444 - binary_accuracy: 0.9924
# Epoch 945/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0434 - binary_accuracy: 0.9912
# Epoch 946/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0389 - binary_accuracy: 0.9943
# Epoch 947/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0399 - binary_accuracy: 0.9911
# Epoch 948/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0380 - binary_accuracy: 0.9960
# Epoch 949/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0432 - binary_accuracy: 0.9900
# Epoch 950/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0530 - binary_accuracy: 0.9849
# Epoch 951/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0338 - binary_accuracy: 0.9956
# Epoch 952/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0441 - binary_accuracy: 0.9891
# Epoch 953/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - binary_accuracy: 0.9785
# Epoch 954/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0916 - binary_accuracy: 0.9739
# Epoch 955/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0315 - binary_accuracy: 0.9958
# Epoch 956/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.0325 - binary_accuracy: 0.9950
# Epoch 957/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0378 - binary_accuracy: 0.9929
# Epoch 958/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.1040 - binary_accuracy: 0.9687
# Epoch 959/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.0393 - binary_accuracy: 0.9941
# Epoch 960/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0445 - binary_accuracy: 0.9910
# Epoch 961/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0460 - binary_accuracy: 0.9883
# Epoch 962/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0343 - binary_accuracy: 0.9929
# Epoch 963/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0355 - binary_accuracy: 0.9943
# Epoch 964/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0370 - binary_accuracy: 0.9950
# Epoch 965/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0401 - binary_accuracy: 0.9902
# Epoch 966/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0578 - binary_accuracy: 0.9823
# Epoch 967/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0379 - binary_accuracy: 0.9911
# Epoch 968/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0760 - binary_accuracy: 0.9680
# Epoch 969/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0446 - binary_accuracy: 0.9857
# Epoch 970/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0315 - binary_accuracy: 0.9971
# Epoch 971/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0359 - binary_accuracy: 0.9934
# Epoch 972/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0404 - binary_accuracy: 0.9963
# Epoch 973/1000
# 57/57 [==============================] - 0s 890us/step - loss: 0.0430 - binary_accuracy: 0.9910
# Epoch 974/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0430 - binary_accuracy: 0.9876
# Epoch 975/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0522 - binary_accuracy: 0.9851
# Epoch 976/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0309 - binary_accuracy: 0.9948
# Epoch 977/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0326 - binary_accuracy: 0.9942
# Epoch 978/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0321 - binary_accuracy: 0.9946
# Epoch 979/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0320 - binary_accuracy: 0.9927
# Epoch 980/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0365 - binary_accuracy: 0.9948
# Epoch 981/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0338 - binary_accuracy: 0.9929
# Epoch 982/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.2059 - binary_accuracy: 0.9315
# Epoch 983/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0364 - binary_accuracy: 0.9930
# Epoch 984/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0353 - binary_accuracy: 0.9958
# Epoch 985/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0330 - binary_accuracy: 0.9938
# Epoch 986/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0313 - binary_accuracy: 0.9967
# Epoch 987/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0326 - binary_accuracy: 0.9946
# Epoch 988/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0331 - binary_accuracy: 0.9940
# Epoch 989/1000
# 57/57 [==============================] - 0s 979us/step - loss: 0.0323 - binary_accuracy: 0.9974
# Epoch 990/1000
# 57/57 [==============================] - 0s 926us/step - loss: 0.0305 - binary_accuracy: 0.9958
# Epoch 991/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0497 - binary_accuracy: 0.9855
# Epoch 992/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0278 - binary_accuracy: 0.9962
# Epoch 993/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0282 - binary_accuracy: 0.9956
# Epoch 994/1000
# 57/57 [==============================] - 0s 873us/step - loss: 0.0352 - binary_accuracy: 0.9938
# Epoch 995/1000
# 57/57 [==============================] - 0s 980us/step - loss: 0.0339 - binary_accuracy: 0.9953
# Epoch 996/1000
# 57/57 [==============================] - 0s 962us/step - loss: 0.0375 - binary_accuracy: 0.9905
# Epoch 997/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0301 - binary_accuracy: 0.9960
# Epoch 998/1000
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0302 - binary_accuracy: 0.9965
# Epoch 999/1000
# 57/57 [==============================] - 0s 944us/step - loss: 0.0381 - binary_accuracy: 0.9921
# Epoch 1000/1000
# 57/57 [==============================] - 0s 997us/step - loss: 0.0401 - binary_accuracy: 0.9935

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
keras_dnn_accuracy = test_accuracy * 100
print("Keras Deep Neural Network accuracy: {}%".format(keras_dnn_accuracy))
# Out:
# 14/14 [==============================] - 0s 767us/step - loss: 0.3517 - binary_accuracy: 0.9402
# Keras Deep Neural Network accuracy: 94.0191388130188%

# %% [markdown]
# It is possible to see that the Keras model performed better than the MPL classifier from sklearn having 1000 epochs in both cases, but also it is possible to see that the computer resources used were pretty different as well. The Keras model consumed more resources than the sklearn model.

# %% [markdown]
# ## Recurrent Neural Network Model

# %%
#For LSTM Model
def sequence_LSTM(df):
    sequence = []
    for i in range(len(df[1])):
        rows = df.iloc[i]
        rows1 = rows.tolist()
        sequence.append(rows1)
    return sequence
        
X_test_LSTM = sequence_LSTM(X_test_rnn)
X_train_sm_LSTM = sequence_LSTM(X_train_sm_rnn)

# %%
# X_train_sm_LSTM = np.array(X_train_sm_LSTM)
# X_test_LSTM = np.array(X_test_LSTM)
# y_train_sm_rnn_array = np.array(y_train_sm_rnn)
# y_test_rnn_array = np.array(y_train_sm_rnn)

X_train_sm_LSTM = np.array(X_train)
X_test_LSTM = np.array(X_test)
# y_train_sm_rnn_array = np.array(y_train)
# y_test_rnn_array = np.array(y_test)

# %%
train_data = X_train_sm_LSTM.reshape(975, 1, 50)
test_data = X_test_LSTM.reshape(418, 1, 50)

# y_train_data = np.array(y_train_sm_rnn)
# y_test_data = np.array(y_test_rnn)

y_train_data = np.array(y_train)
y_test_data = np.array(y_test)

# %%
# max_review_length = 50
# x_train_padded = keras.preprocessing.sequence.pad_sequences(X_train_sm_LSTM)
# x_test_padded  = keras.preprocessing.sequence.pad_sequences(X_test_LSTM)

# %%
# # from keras.utils import to_categorical
# classes = 2
# y_train_sparse = keras.utils.to_categorical(y_train_sm_rnn, num_classes=classes)
# y_test_sparse = keras.utils.to_categorical(y_test_rnn, num_classes=classes)

# %%
# embedding_vecor_length = 512
# max_review_length = 50
# vocab_size = 50
# input_dim = 50
# output_dim = 50

model1 = keras.Sequential()
#model1.add(keras.layers.Embedding(input_dim,output_dim))
#model1.add(keras.layers.LSTM(100, input_shape=(1811,50), return_sequences=True))
#model1.add(keras.layers.LSTM(100))
model1.add(keras.layers.LSTM(100, input_shape = (975,50), return_sequences=True))
model1.add(keras.layers.LSTM(100, return_sequences=True))
model1.add(keras.layers.LSTM(100))
model1.add(keras.layers.Dense(1, activation = 'sigmoid'))

model1.summary()

# Model Compilation
model1.compile(optimizer='adam',loss='binary_crossentropy',metrics=['BinaryAccuracy'])

model1.fit(
    train_data,
    y_train_data,
    epochs=10,
    #batch_size=500,
    validation_data=(test_data, y_test_data),
    verbose=0)

scores1 = model1.evaluate(test_data, y_test_data, verbose=2)
keras_rnn_accuracy = scores1[1]*100
print("LSTM Accuracy: %.2f%%" % (keras_rnn_accuracy))
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_46 (LSTM)               (None, 975, 100)          60400
# _________________________________________________________________
# lstm_47 (LSTM)               (None, 975, 100)          80400
# _________________________________________________________________
# lstm_48 (LSTM)               (None, 100)               80400
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 221,301
# Trainable params: 221,301
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 975, 50) for input KerasTensor(type_spec=TensorSpec(shape=(None, 975, 50), dtype=tf.float32, name='lstm_46_input'), name='lstm_46_input', description="created by layer 'lstm_46_input'"), but it was called on an input with incompatible shape (None, 1, 50).
# WARNING:tensorflow:Model was constructed with shape (None, 975, 50) for input KerasTensor(type_spec=TensorSpec(shape=(None, 975, 50), dtype=tf.float32, name='lstm_46_input'), name='lstm_46_input', description="created by layer 'lstm_46_input'"), but it was called on an input with incompatible shape (None, 1, 50).
# WARNING:tensorflow:Model was constructed with shape (None, 975, 50) for input KerasTensor(type_spec=TensorSpec(shape=(None, 975, 50), dtype=tf.float32, name='lstm_46_input'), name='lstm_46_input', description="created by layer 'lstm_46_input'"), but it was called on an input with incompatible shape (None, 1, 50).
# 14/14 - 0s - loss: 0.2467 - binary_accuracy: 0.9330
# LSTM Accuracy: 93.30%

# %% [markdown]
# ## Performance Comparison

# %%
performance = [snn_accuracy,nn0_accuracy,dnn_accuracy,keras_dnn_accuracy,keras_rnn_accuracy ]

y = ['snn','snn_scratch','sklearn_dnn','keras_dnn', 'keras_rnn']

fig, ax = plt.subplots(figsize = (12,6))    
ax.bar(y, performance, color = ['lightseagreen', 'tomato', 'darkmagenta', 'crimson', 'olive'])
plt.title('Performance of each Model', fontsize = 25)
plt.ylabel('Accuracy',fontsize = 15)  
plt.tick_params(axis="x", labelsize=15)
plt.tick_params(axis="y", labelsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# As it is seen in the plot above the best 2 options is a deep learning model with 2 hidden layers and an RNN model using LTSM.

# %% [markdown]
# # Summary of findings
#
# - As seen in the analysis it seems that the best 2 options where the deep learning model and the LSTM model, both using keras, with 94% and 93% respectively. Something to take into account is that from Milestone 2 Random Forest got a 97% and it is to an extend a white box algorithm which gives the advantage of providing direct feedback on what features are more relevant to the prediction of the quality of the diaper.
#
#
# - Deep learning models even though powerful, it should be treated and done with a lot of care. Meaning there is a lot of that needs to be consider before jumping to use a more complex model that potentially could have been done with another machine learning algorithm that would provide a better advantage. Among other things: expertise on the problem that wants to be solved, expertise in the kind of deep learning model that wants to be used, clear understanding of the assumptions and limitations of the problem and model and maybe more importantly a really good idea of the potential bias intrinsic to data that comes from an imperfect word.
#
#
# - Another important point to notice is the selection of the best hyperparameters, a good way to start is by using best practices in regards the kind of problem that is being analyzed and talking to experts on the matter. Once a good guess of the best options is collected, then a grid search (or random search) around that good guess might be a great way to obtain the best hyperparameters for the mode, which is as important as any part of the analysis and machine learning model. If it is not possible to obtain a good guess, just an exploration by using grid or random search can provide a very good estimate of these parameters.
#
#
# - Some recommendations for the manufacturer would be:
#
#     - *Keep getting data, the more data we have the better models it would be able to develop.*
#     - *That leads me to the 2nd point, the other suggestion is to make sure the check their sensors and data periodically to make sure no false information is being input to the model. This could be done by working on periodic checks on the instrumentation (trends and direct comparisons with previous/calibrated states).*
#     - *The list of the most relevant 50 sensors can be found in this analysis, which are the ones that we have to ensure receive proper maintenance. No to say that the other sensors does not matter, but the ones included in this analysis are the ones that provide better inside to the model in relation to the quality of the diapers.*

# %% [markdown]
# # Feedback Request:
#
# 1. What is the best way or the most practice way of getting hyperparameters for a deep learning model,  especially when using tensorflow and keras?
#
#
# 2. What is the best (or more common) way of knowing the number of layer and neurons for a problem like this one? Knowing that exploring all the combinations is very computationally expensive how do you sample a subset where the probability of higher accuracy is given?
#
#
# 3. In which case make sense to add other kind of deep layers to the model and not only dense layers but others?
#
#
# 4. Deep learning being a black box algorithm what feedback usually can be obtain from the model? what other performance parameters could be significant for this kind of manufacturing problems?
